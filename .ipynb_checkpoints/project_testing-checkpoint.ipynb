# %%
#Test JSON Access of output files.
#Added download from S3 Bucket.
import json
import boto3
import botocore

s3 = boto3.resource('s3', aws_access_key_id='AKIAIETDXV22EFPW27BA', aws_secret_access_key='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')

content_object = s3.Object('capstonedatag58', 'harvey_scrape/files/harvey_output.json')
file_content = content_object.get()['Body'].read().decode('utf-8')
json_content = json.loads(file_content)

# with open('harvey/harvey_output/harvey_output_9.json') as f:
#     data = json.loads(f.read())
#     print(len(data))
#     for i in data: 
#         if '0036f0eae24b42f922befe3cd1019a23c59b3dbb' in i['image_hash_ids']:
#             print(i['title'])
#             print(i['base_url'])
#             print(len(i['text'].lower().split()))
# Out:
# {'text': 'window.SCRIPPS_ACONFIG_B = {"matchType" : "section", "appNexusTemplate" : "default", "zone" : "money/local_business_news/dan_monk/landing", "kw" : "latest news,articles from wcpo digital reporter dan monk on wcpo.com,wcpo,news channel 9,9 on your side,video,live stream video,cincinnati news,northern kentucky news,indiana news,weather,sports,cincinnati reds,facebook,google maps,youtube,you tube,abc news,utube,face book,yahoo,ohio,local,state,us,world,america,political,obama,cincinnati business news,kentucky business news,cincinnati sports news,kentucky sports news,cincinnati investigation news,kentucky investigation news,cincinnati investigation news,cincinnati weird news,kentucky weird news,cincinnati education news,kentucky education news,cincinnati obituaries,kentucky obituaries,indiana obituaries,cincinnati weather news,kentucky weather news,indiana weather news,cincinnati forecast,kentucky forecast,indiana forecast,cincinnati 7 day forecast,kentucky 7 day forecast,india
# ...

# %%
#Run basic match Template on S3 images

# %%
#Clean text from website
from bs4 import BeautifulSoup
from bs4.element import Comment
import requests
import numpy as np
import string
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer
import re
import sys

def tag_visible(element):
    if element.parent.name in ['style', 'script', 'head', 'title', 'meta', '[document]']:
        return False
    if isinstance(element, Comment):
        return False
    return True

def text_from_html(body):
    soup = BeautifulSoup(body, 'html.parser')
    texts = soup.findAll(text=True)
    visible_texts = filter(tag_visible, texts)  
    return u" ".join(t.strip() for t in visible_texts)

url = 'https://en.wikipedia.org/wiki/Hurricane_Harvey'
body = requests.get(url).content

text = text_from_html(req)

def clean_text(text):
    wordnet = WordNetLemmatizer()
    stop = set(stopwords.words('english'))
    
    txt = re.sub('['+string.punctuation+']', '', text.lower())
    txt = word_tokenize(txt)
    txt = [word for word in txt if word not in stop]
    txt = [wordnet.lemmatize(word) for word in txt if not word.isdigit()]
    print(txt)
    
print(sys.getsizeof(text))
print(sys.getsizeof(sys.intern(text.lower())))
# Out:
# 160394
# 160394
